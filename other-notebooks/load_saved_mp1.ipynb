# %%
 # !pip install bertopic fasttext nepalitokenizer nepali-stemmer pymongo snowballstemmer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.1/492.1 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 17.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Mounting Google Drive for fasttext file
from google.colab import drive

import pandas as pd

drive.mount('/content/gdrive/', force_remount=True)
# %cd gdrive/MyDrive
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive

# %%
#Import the news headline in dataframe named news_text_df from
import pymongo
import pandas as pd

myclient = pymongo.MongoClient("mongodburl")
mydb = myclient["major-project"]
mycol = mydb["news"]

mydoc = mycol.find({},{"Headline":1})

news_text_df = pd.DataFrame(list(mydoc))
news_text_df.head()
# Out:
#                         _id                                           Headline
# 0  640751c6cd3e9c69b1269877   राष्ट्रपति निर्वाचनका लागि मतदान केन्द्र निर्माण
# 1  640751c6cd3e9c69b1269878                          सभामुख घिमिरे बहराइन जाने
# 2  640751c6cd3e9c69b1269879  रवि लामिछानेको मुद्दामा फैसलाको पूर्णपाठले के ...
# 3  640751c6cd3e9c69b126987a  मुस्ताङमा बौद्ध विश्वविद्यालय खोल्न सरकारले स्...
# 4  640751c6cd3e9c69b126987b  रवि लामिछानेको राहदानी विवादबारे के बोल्यो सर्...

# %%
#Import the news headline in dataframe named news_text_df from
import pymongo
import pandas as pd

myclient = pymongo.MongoClient("mongodburl")

mydb = myclient["major-project"]
mycol = mydb["news_np_lb"]

mydoc = mycol.find({},{"headline":1})

news_text_df_np = pd.DataFrame(list(mydoc))
news_text_df_np.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ff2a64938e3d> in <cell line: 12>()
#      10 mydoc = mycol.find({},{"headline":1})
#      11
# ---> 12 news_text_df_np = pd.DataFrame(list(mydoc))
#      13 news_text_df_np.head()
#
# /usr/local/lib/python3.9/dist-packages/pymongo/cursor.py in next(self)
#    1246         if self.__empty:
#    1247             raise StopIteration
# -> 1248         if len(self.__data) or self._refresh():
#    1249             return self.__data.popleft()
#    1250         else:
#
# /usr/local/lib/python3.9/dist-packages/pymongo/cursor.py in _refresh(self)
#    1186                 self.__comment,
#    1187             )
# -> 1188             self.__send_message(g)
#    1189
#    1190         return len(self.__data)
#
# /usr/local/lib/python3.9/dist-packages/pymongo/cursor.py in __send_message(self, operation)
#    1050
# ...

# %%
news_text_df_np
# Out:
#                              _id                      date  \
# 0       6443e8c463eb3a1f4da1fe79               २४ माघ २०७९
# 1       6443e8c463eb3a1f4da1fe7a               २४ माघ २०७९
# 2       6443e8c463eb3a1f4da1fe7b               २३ माघ २०७९
# 3       6443e8c463eb3a1f4da1fe7c               २३ माघ २०७९
# 4       6443e8c463eb3a1f4da1fe7d               २३ माघ २०७९
# ...                          ...                       ...
# 263871  6443ec0e63eb3a1f4da6053c  २०७९ फागुन  १६ गते १९:३१
# 263872  6443ec0e63eb3a1f4da6053d  २०७९ फागुन  १६ गते १९:२५
# 263873  6443ec0e63eb3a1f4da6053e                      None
# 263874  6443ec0e63eb3a1f4da6053f  २०७९ फागुन  १६ गते १८:३७
# 263875  6443ec0e63eb3a1f4da60540  २०७९ फागुन  १६ गते १८:३४
#
#                                                  headline  \
# 0       नेपालमा पश्चिमी वायुको प्रभाव, उच्च पहाडी क्षे...
# 1                    रेडक्रसको भ्रष्टाचारमा अन्देखा किन ?
# 2               तीन थान एयर गनसहित चार भारतीय नियन्त्रणमा
# ...

# %%
import fasttext
import numpy as np
from bertopic.backend import BaseEmbedder
## Creating custom embedder using fasttext
class CustomEmbedder(BaseEmbedder):
    def __init__(self, embedding_model):
        super().__init__()
        self.embedding_model = embedding_model

    def embed(self, documents, verbose=False):
        results_from_fasttext = []
        for sentence in documents:
            embeddings_fasttext = self.embedding_model.get_sentence_vector(sentence).tolist()
            embeddings_fasttext = np.asarray(embeddings_fasttext).reshape(-1,300).flatten()
            results_from_fasttext.append(embeddings_fasttext)

        embeddings= np.array(results_from_fasttext)
        return embeddings

# Create custom backend
ft_ne = fasttext.load_model("/content/gdrive/MyDrive/major-project/cc.ne.300.bin")
custom_embedder = CustomEmbedder(embedding_model=ft_ne)

# %%
from nepalitokenizer import NepaliTokenizer
def nepali_tokenizer(text):
    # tokenize the text using the BERT tokenizer
    tokens = tokenize.tokenizer(text)
    # return the token list as a string
    return tokens

tokenize = NepaliTokenizer()

#I think this can be optimmized if tokenize.tokenizer is directly passed to the count vectorizer instead of creating function. Doing this we may not have to write this function always while loading model.

# %%
##Loading pre saved model
from bertopic import BERTopic
topic_model = BERTopic.load("/content/gdrive/MyDrive/major-project/pro_first_2k_data")

# %%
itm=topic_model.visualize_topics()

# %%
htmp= topic_model.visualize_heatmap()

# %%
itm.write_html("/content/gdrive/MyDrive/major-project/topic_map.html")

# %%
htmp.write_html("/content/gdrive/MyDrive/major-project/heat_map.html")

# %%
topic_model.get_topic_info()
# Out:
#      Topic   Count                                   Name
# 0       -1  140642  -1_सरकार_प्रधानमन्त्री_प्रचण्ड_कोरोना
# 1        0   11140              0_विश्वकप_क्रिकेट_जित_खेल
# 2        1    5130          1_दुर्घटना_घाइते_मोटरसाइकल_बस
# 3        2    4360          2_विजयी_मेयर_निर्वाचित_उपमेयर
# 4        3    4073             3_पक्राउ_किलो_तस्करी_बरामद
# ..     ...     ...                                    ...
# 319    318       5            318_मान्_कार्टुन_होइन’_छोड्
# 320    319       5            319_एक्लो_त्रसित_चीन_‘नेपाल
# 321    320       5      320_चरण_अन्तिम_विमानस्थल_बन्दरगाह
# 322    321       5         321_लकडाउन_हुँदैन’_निस्क_पालना
# 323    322       5             322_’_भोकभो_‘सरकार_भिडियाे
#
# [324 rows x 3 columns]

# %%
topic_model.visualize_barchart(top_n_topics=8)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Creating embeddings for new topics
embeddings = custom_embedder.embed(news_text_df["Headline"])

# %%
# Predict topics for test_docs
predicted_topics, predicted_probs = topic_model.transform(news_text_df["Headline"],embeddings)

# %%
news_text_df["predicted_topics_label"] = predicted_topics

# %%
news_text_df
# Out:
#                            _id  \
# 0     640751c6cd3e9c69b1269877
# 1     640751c6cd3e9c69b1269878
# 2     640751c6cd3e9c69b1269879
# 3     640751c6cd3e9c69b126987a
# 4     640751c6cd3e9c69b126987b
# ...                        ...
# 2600  640751c6cd3e9c69b126a29f
# 2601  640751c6cd3e9c69b126a2a0
# 2602  640751c6cd3e9c69b126a2a1
# 2603  640751c6cd3e9c69b126a2a2
# 2604  640751c6cd3e9c69b126a2a3
#
#                                                Headline  \
# 0      राष्ट्रपति निर्वाचनका लागि मतदान केन्द्र निर्माण
# 1                             सभामुख घिमिरे बहराइन जाने
# 2     रवि लामिछानेको मुद्दामा फैसलाको पूर्णपाठले के ...
# 3     मुस्ताङमा बौद्ध विश्वविद्यालय खोल्न सरकारले स्...
# 4     रवि लामिछानेको राहदानी विवादबारे के बोल्यो सर्...
# ...                                                 ...
# 2600                    पर्वतीय पथप्रदर्शकहरू आन्दोलित
# 2601     कालीञ्चोकमा हिउँ खेल्नेको भीड^ होटलहरु भरिभराउ
# 2602  वास्तविक मधेसको स्वाद दिने त्यो नरैनापुरको यात...
# ...

# %%
news_text_df[news_text_df["predicted_topics_label"]==-1].count()
# Out:
# _id                       1409
# Headline                  1409
# predicted_topics_label    1409
# dtype: int64

# %%
import snowballstemmer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword= stopwords.words('nepali')
stemmer = snowballstemmer.stemmer('nepali')
news_text_df["headline_stemmed"] = news_text_df["headline"].apply(tokenize.tokenizer)
news_text_df["headline_stemmed"] = news_text_df["headline_stemmed"].apply(stemmer.stemWords)
news_text_df["headline_stemmed"]= news_text_df["headline_stemmed"].apply(lambda x: " ".join([w for w in x if w not in stopword]))

# %%
# Creating embeddings for new topics
embeddings_steemed = custom_embedder.embed(news_text_df["headline_stemmed"])
# Predict topics for test_docs
predicted_topics, predicted_probs = topic_model.transform(news_text_df["headline_stemmed"],embeddings_steemed)

# %%
news_text_df["predicted_topics_label_stm"] = predicted_topics

# %%
news_text_df
# Out:
#                            _id  \
# 0     640751c6cd3e9c69b1269877
# 1     640751c6cd3e9c69b1269878
# 2     640751c6cd3e9c69b1269879
# 3     640751c6cd3e9c69b126987a
# 4     640751c6cd3e9c69b126987b
# ...                        ...
# 2600  640751c6cd3e9c69b126a29f
# 2601  640751c6cd3e9c69b126a2a0
# 2602  640751c6cd3e9c69b126a2a1
# 2603  640751c6cd3e9c69b126a2a2
# 2604  640751c6cd3e9c69b126a2a3
#
#                                                Headline  \
# 0      राष्ट्रपति निर्वाचनका लागि मतदान केन्द्र निर्माण
# 1                             सभामुख घिमिरे बहराइन जाने
# 2     रवि लामिछानेको मुद्दामा फैसलाको पूर्णपाठले के ...
# 3     मुस्ताङमा बौद्ध विश्वविद्यालय खोल्न सरकारले स्...
# 4     रवि लामिछानेको राहदानी विवादबारे के बोल्यो सर्...
# ...                                                 ...
# 2600                    पर्वतीय पथप्रदर्शकहरू आन्दोलित
# 2601     कालीञ्चोकमा हिउँ खेल्नेको भीड^ होटलहरु भरिभराउ
# 2602  वास्तविक मधेसको स्वाद दिने त्यो नरैनापुरको यात...
# ...

# %%
news_text_df[news_text_df["predicted_topics_label_stm"]==-1].count()
# Out:
# _id                           1332
# Headline                      1332
# predicted_topics_label        1332
# headline_stemmed              1332
# predicted_topics_label_stm    1332
# dtype: int64

# %%
predicted_probs
# Out:
# array([0.73440728, 0.        , 0.56953432, ..., 0.        , 0.        ,
#        0.94662282])

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents
cleaned_docs = news_text_df["headline_stemmed"]

# Extract vectorizer and tokenizer from BERTopic
vectorizer = topic_model.vectorizer_model
tokenizer = nepali_tokenizer

# Get topics
topics= topic_model.get_topics()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)]
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words,
                                 texts=tokens,
                                 corpus=corpus,
                                 dictionary=dictionary,
                                 coherence='c_v')
coherence = coherence_model.get_coherence()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'headline_stemmed'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
per_topic = coherence_model.get_coherence_per_topic()
len(per_topic)
# Out:
# 323

# %%
# Preprocess documents
cleaned_docs = news_text_df["headline_stemmed"]

# Extract vectorizer and tokenizer from BERTopic
vectorizer = topic_model.vectorizer_model
tokenizer = nepali_tokenizer

# Get topics
topics= topic_model.get_topics()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)]
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words,
                                 texts=tokens,
                                 corpus=corpus,
                                 dictionary=dictionary,
                                 coherence='c_')
coherence_umass = coherence_model.get_coherence()
coherence_umass
# Out:
# -0.3973931294905585

# %%
import numpy as np
embeddings = np.load("/content/gdrive/MyDrive/major-project/pro_first_2k_data_embeddings.npy")

# %%
embeddings.shape
# Out:
# (263875, 300)

# %%
from sklearn.metrics import silhouette_score
# Generate `X` and `labels` only for non-outlier topics (as they are technically not clusters)
umap_embeddings = topic_model.umap_model.transform(embeddings)
indices = [index for index, topic in enumerate(topics) if topic != -1]
X = umap_embeddings[np.array(indices)]
labels = [topic for index, topic in enumerate(topics) if topic != -1]

# Calculate silhouette score
silhouette_score(X, labels)

# %%
X.shape
# Out:
# (323, 5)

# %%
len(labels)
# Out:
# 323

# %%
## SAVING LABEL NAME TO DATABASE
topic_info= topic_model.get_topic_info()

# %%
topic_info
# Out:
#      Topic   Count                                   Name
# 0       -1  140642  -1_सरकार_प्रधानमन्त्री_प्रचण्ड_कोरोना
# 1        0   11140              0_विश्वकप_क्रिकेट_जित_खेल
# 2        1    5130          1_दुर्घटना_घाइते_मोटरसाइकल_बस
# 3        2    4360          2_विजयी_मेयर_निर्वाचित_उपमेयर
# 4        3    4073             3_पक्राउ_किलो_तस्करी_बरामद
# ..     ...     ...                                    ...
# 319    318       5            318_मान्_कार्टुन_होइन’_छोड्
# 320    319       5            319_एक्लो_त्रसित_चीन_‘नेपाल
# 321    320       5      320_चरण_अन्तिम_विमानस्थल_बन्दरगाह
# 322    321       5         321_लकडाउन_हुँदैन’_निस्क_पालना
# 323    322       5             322_’_भोकभो_‘सरकार_भिडियाे
#
# [324 rows x 3 columns]

# %%
topic_prediction = topic_model.topics_[:]

# %%
len(topic_prediction)
# Out:
# 263875

# %%
news_text_df_np["topic_label"] = topic_prediction

# %%
news_text_df_np
# Out:
#                              _id                      date  \
# 0       6443e8c463eb3a1f4da1fe79               २४ माघ २०७९
# 1       6443e8c463eb3a1f4da1fe7a               २४ माघ २०७९
# 2       6443e8c463eb3a1f4da1fe7b               २३ माघ २०७९
# 3       6443e8c463eb3a1f4da1fe7c               २३ माघ २०७९
# 4       6443e8c463eb3a1f4da1fe7d               २३ माघ २०७९
# ...                          ...                       ...
# 263870  6443ec0e63eb3a1f4da6053c  २०७९ फागुन  १६ गते १९:३१
# 263871  6443ec0e63eb3a1f4da6053d  २०७९ फागुन  १६ गते १९:२५
# 263872  6443ec0e63eb3a1f4da6053e                      None
# 263873  6443ec0e63eb3a1f4da6053f  २०७९ फागुन  १६ गते १८:३७
# 263874  6443ec0e63eb3a1f4da60540  २०७९ फागुन  १६ गते १८:३४
#
#                                                  headline  \
# 0       नेपालमा पश्चिमी वायुको प्रभाव, उच्च पहाडी क्षे...
# 1                    रेडक्रसको भ्रष्टाचारमा अन्देखा किन ?
# 2               तीन थान एयर गनसहित चार भारतीय नियन्त्रणमा
# ...

# %%
#For inserting topic label i.e numeric value of cluster
for index,row in news_text_df_np.iterrows():
    by_id  = mycol.find_one_and_update({"_id":row["_id"]},
                                       {"$set":
                                            {"topic_label": row["topic_label"]}

                                       },upsert=False)

## Goes exceuting for very long. Doesnot work.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6daa06e48882> in <cell line: 2>()
#       1 #For inserting topic label i.e numeric value of cluster
#       2 for index,row in news_text_df_np.iterrows():
# ----> 3     by_id  = mycol.find_one_and_update({"_id":row["_id"]},
#       4                                        {"$set":
#       5                                             {"topic_label": row["topic_label"]}
#
# /usr/local/lib/python3.9/dist-packages/pymongo/collection.py in find_one_and_update(self, filter, update, projection, sort, upsert, return_document, array_filters, hint, session, let, comment, **kwargs)
#    3181         if comment is not None:
#    3182             kwargs["comment"] = comment
# -> 3183         return self.__find_and_modify(
#    3184             filter,
#    3185             projection,
#
# ...

# %%
# merge the two dataframes based on the 'ID' column
merged_df = pd.merge(news_text_df_np, topic_info, left_on='topic_label', right_on='Topic', how='left')

# %%
# add the 'Value' column from df2 to df1
news_text_df_np['topic_name'] = merged_df['Name']

# print the resulting dataframe
news_text_df_np
# Out:
#                              _id                      date  \
# 0       6443e8c463eb3a1f4da1fe79               २४ माघ २०७९
# 1       6443e8c463eb3a1f4da1fe7a               २४ माघ २०७९
# 2       6443e8c463eb3a1f4da1fe7b               २३ माघ २०७९
# 3       6443e8c463eb3a1f4da1fe7c               २३ माघ २०७९
# 4       6443e8c463eb3a1f4da1fe7d               २३ माघ २०७९
# ...                          ...                       ...
# 263870  6443ec0e63eb3a1f4da6053c  २०७९ फागुन  १६ गते १९:३१
# 263871  6443ec0e63eb3a1f4da6053d  २०७९ फागुन  १६ गते १९:२५
# 263872  6443ec0e63eb3a1f4da6053e                      None
# 263873  6443ec0e63eb3a1f4da6053f  २०७९ फागुन  १६ गते १८:३७
# 263874  6443ec0e63eb3a1f4da60540  २०७९ फागुन  १६ गते १८:३४
#
#                                                  headline  \
# 0       नेपालमा पश्चिमी वायुको प्रभाव, उच्च पहाडी क्षे...
# 1                    रेडक्रसको भ्रष्टाचारमा अन्देखा किन ?
# 2               तीन थान एयर गनसहित चार भारतीय नियन्त्रणमा
# ...

# %%
collection = mydb["news_np_lb"]
data = news_text_df_np.to_dict(orient='records')

# insert the data into the MongoDB collection
collection.insert_many(data)

# %%
# !pip freeze >requirements.txt

# %%
# !python --version
# Out:
# Python 3.9.16
